# %% [markdown]
# # TYPES OF DATA PLOTS FOR VIZUALISATION

# %% [markdown]
# To visualize the data using beatutiful charts we will first have to import the modules and construct the data.

# %%
import pandas as pd

#creating the dataframe
df = pd.DataFrame({'Country':['Russia','Canada','China','USA','Brazil','Australia','India','Argentina','Kazakhstan','Algeria'],
                   'Total Area (km.sq)':[17098242,9984670,9706961,9372610,8515767,7692024,3287590,2780400,2724900,2381741],
                   'Land Area (km.sq)':[16376870,9093510,9388211,9147420,8358140,7682300,2973190,2736690,2699700,2381740],
                   'Landmass (%)':[11,6.1,6.3,6.1,5.6,5.2,2,1.8,1.8,1.6],
                   'Fertility Rate': [1.8,1.5,1.7,1.8,1.7,1.8,2.2,2.3,2.8,3.1],
                   'Annual Population Change (%)': [0.04,0.89,0.39,0.59,0.72,1.18,0.99,0.93,1.21,1.85]})
df.shape
# Out:
# (10, 6)

# %%
df
# Out:
#       Country  Total Area (km.sq)  Land Area (km.sq)  Landmass (%)  \
# 0      Russia            17098242           16376870          11.0
# 1      Canada             9984670            9093510           6.1
# 2       China             9706961            9388211           6.3
# 3         USA             9372610            9147420           6.1
# 4      Brazil             8515767            8358140           5.6
# 5   Australia             7692024            7682300           5.2
# 6       India             3287590            2973190           2.0
# 7   Argentina             2780400            2736690           1.8
# 8  Kazakhstan             2724900            2699700           1.8
# 9     Algeria             2381741            2381740           1.6
#
#    Fertility Rate  Annual Population Change (%)
# 0             1.8                          0.04
# 1             1.5                          0.89
# 2             1.7                          0.39
# ...

# %% [markdown]
# ## 1. BAR CHART
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally. A vertical bar chart is sometimes called a column chart.
#
# It shows comparisons among discrete categories. One axis of the chart shows the specific categories being compared, and the other axis represents a measured value. Some bar graphs present bars clustered in groups of more than one, showing the values of more than one measured variable which we will be discussing in this NoteBook.

# %% [markdown]
# ### 1.1. VERTICAL BAR CHART

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np

# %%
df.plot(kind='bar',
        x='Country',
        y='Fertility Rate',
        figsize=(15,5),
        color='indigo',
        grid=True)

plt.title("Countries Ranked By Fertility Rate")
# Out:
# Text(0.5, 1.0, 'Countries Ranked By Fertility Rate')

# %% [markdown]
# ### 1.2. HORIZONTAL BAR CHART

# %%
df.plot(kind='barh',
        x='Country',
        y='Fertility Rate',
        figsize=(14,10),
        color='indigo',
        grid=True)

plt.title("Countries Ranked By Fertility Rate")
# Out:
# Text(0.5, 1.0, 'Countries Ranked By Fertility Rate')

# %% [markdown]
# ### 1.3. GROUPED BAR CHART
# The grouped bar graph is also called the clustered bar graph, which is used to represent the discrete value for more than one object that shares the same category. In this type of bar chart, the total number of instances are combined into a single bar.
#
# In other words, a grouped bar graph is a type of bar graph in which different sets of data items are compared. Here, a single colour is used to represent the specific series across the set. The grouped bar graph can be represented using both vertical and horizontal bar charts.

# %% [markdown]
# ### 1.3.1. VERTICAL GROUPED BAR CHART

# %%
df.plot(kind='bar',
        x='Country',
        y=['Annual Population Change (%)', 'Fertility Rate'],
        figsize=(15,5),
        grid=True)

plt.title("Annual Population Change (%) VS Fertility Rate")
# Out:
# Text(0.5, 1.0, 'Annual Population Change (%) VS Fertility Rate')

# %% [markdown]
# ### 1.3.2. HORIZONTAL GROUPED BAR CHART

# %%
df.plot(kind='barh',
        x='Country',
        y=['Annual Population Change (%)', 'Fertility Rate'],
        figsize=(14,10),
        grid=True)

plt.title("Annual Population Change (%) VS Fertility Rate")
# Out:
# Text(0.5, 1.0, 'Annual Population Change (%) VS Fertility Rate')

# %% [markdown]
# ### 1.4. STACKED BAR CHART
# A stacked bar graph (or stacked bar chart) is a chart that uses bars to show comparisons between categories of data, but with ability to break down and compare parts of a whole. Each bar in the chart represents a whole, and segments in the bar represent different parts or categories of that whole.
#
# Stacked bar charts are not suited to data sets having both positive and negative values since stacked bar charts present the information in the same sequence on each bar.

# %% [markdown]
# ### 1.4.1 VERTICAL STACKED BAR CHART

# %%
df.plot(kind='bar',
        x='Country',
        y=['Total Area (km.sq)', 'Land Area (km.sq)'],
        figsize=(15,5),
        grid=True,
        stacked=True)

plt.title("Total Area VS Total Land Area Covered (in square km)")
# Out:
# Text(0.5, 1.0, 'Total Area VS Total Land Area Covered (in square km)')

# %% [markdown]
# ### 1.4.2 HORIZONTAL STACKED BAR CHART

# %%
df.plot(kind='barh',
        x='Country',
        y=['Total Area (km.sq)', 'Land Area (km.sq)'],
        figsize=(14,10),
        grid=True,
        stacked=True)

plt.title("Total Area VS Total Land Area Covered (in square km)")
# Out:
# Text(0.5, 1.0, 'Total Area VS Total Land Area Covered (in square km)')

# %% [markdown]
# ## 2. LINE CHART
# A line graph is a unique graph which is commonly used in statistics. It represents the change in a quantity with respect to another quantity. This variation is usually plotted in a two-dimensional XY plane. If the relation including any two measures can be expressed utilizing a straight line in a graph, then such graphs are called line charts or line graphs.

# %%
df.plot(kind='line',
        x='Total Area (km.sq)',
        y='Landmass (%)',
        xlabel='Total Area (square KM)',
        ylabel="Landmass (%)",
        figsize=(15,5),
        grid=True,
        marker='o',
        linestyle='-',
        color='b')

plt.title("Countrywise Variation of Total Area W.R.T Landmass Percentage")
# Out:
# Text(0.5, 1.0, 'Countrywise Variation of Total Area W.R.T Landmass Percentage')

# %% [markdown]
# ## 3. MULTILINE CHART

# %%
plt.figure(figsize=(15, 7))

plt.plot(df['Fertility Rate'],
         label='Fertility Rate',
         color='blue',
         linestyle='-.',
         marker='o',
         linewidth=1.5)

plt.plot(df['Annual Population Change (%)'],
         label='Annual Population Change (in %)',
         color='red',
         linestyle='--',
         marker='o',
         linewidth=1.5)

plt.title('Variation in Fertility Rate and Annual Population Change')
plt.ylabel('Magnitude')

no_of_countries = np.arange(start=0, stop=len(df['Country']), step=1)
country = list(df['Country']) 

plt.xticks(ticks=no_of_countries, labels=country)

plt.legend()
plt.show()

# %% [markdown]
# ## 4. PIE CHART
# A pie chart is a circular statistical graphic, which is divided into slices to illustrate numerical proportion. In a pie chart, the arc length of each slice is proportional to the quantity it represents. Pie charts are often used in business. Examples include showing percentages of types of customers, percentage of revenue from different products, and profits from different countries. Pie charts can be helpful for showing the relationship of parts to the whole when there are a small number of levels.

# %%
plt.figure(figsize=(8, 8))
area = list(df['Total Area (km.sq)'])
country = list(df['Country']) 

plt.pie(area, labels=country, startangle=0, shadow=True)
plt.legend()
plt.show()

# %% [markdown]
# ## 5. EXPLODED PIE CHART

# %%
plt.figure(figsize=(8, 8))
fr = list(df['Fertility Rate'])
country = list(df['Country']) 

explosion = [0.2, 0,0, 0, 0.2, 0, 0.2, 0, 0, 0]

plt.pie(fr, labels=country, startangle=0, explode=explosion, shadow=True)
plt.legend()
plt.show()

# %% [markdown]
# ## 6. SCATTER PLOT
# A scatter plot is a diagram drawn between two distributions of variables X and Y on a two dimensional plane. Scatter plot is used as an initial screening tool while analyzing two variables for any relationship (linear, non-linear, inverse relationships) that may exist between them.

# %%
df.plot(kind='scatter',
        x='Country',
        y='Annual Population Change (%)',   
        s=300,#determines dot thickness
        xlabel='Country Name',
        ylabel="Annual Population Change (in %)",
        figsize=(15,5),
        grid=True,
        color='b')

plt.title("Scatter Plot Representing Countriwise Yearly Population Change (in %)")
# Out:
# Text(0.5, 1.0, 'Scatter Plot Representing Countriwise Yearly Population Change (in %)')

# %% [markdown]
# ## 7. BUBBLE CHART
# Bubble charts display data as a cluster of circles. The required data to create bubble chart needs to have the xy coordinates, size of the bubble and the colour of the bubbles. The colours can be supplied by the library itself. It is an extension of the scatter plot used to look at relationships between three numeric variables. Each dot in a bubble chart corresponds with a single data point, and the variables' values for each point are indicated by horizontal position, vertical position, and dot size.

# %%
plt.figure(figsize=(15, 5))
plt.scatter('Fertility Rate', 'Annual Population Change (%)', s=700, c='r', alpha=0.5, data=df)
plt.scatter('Landmass (%)', 'Fertility Rate', s=1500, c='g', alpha=0.5, data=df)
plt.scatter('Landmass (%)', 'Annual Population Change (%)', s=400, c='b', alpha=0.5, data=df)
plt.xlabel("X-coordinate", size=16)
plt.ylabel("Y-coordinate", size=16)
# Out:
# Text(0, 0.5, 'Y-coordinate')
